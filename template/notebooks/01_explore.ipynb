# %% [markdown]
# # Data exploration
#
# Starter notebook. Replace the demo frame below with your own data from `../data/`.

# %%
import pandas as pd

df = pd.DataFrame({"example": [1, 2, 3]})
# df = pd.read_csv("../data/your_file.csv")
df.head()
